# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Reading ratings file
# Ignore the timestamp column

# Reading movies file
df = pd.read_csv('movies_2019.csv',usecols=['name', 'genre'])

# %%
# Break up the big genre string into a string array
df['genre'] = df['genre'].str.split('|')
# Convert genres to string value
df['genre'] = df['genre'].fillna("").astype('str')
df
# Out:
#                                             genre  \
# 0         ['Drama, Sci-Fi, Thriller            ']
# 1       ['Action, Adventure, Family            ']
# 2            ['Action, Crime, Drama            ']
# 3    ['Animation, Action, Adventure            ']
# 4        ['Comedy, Fantasy, Romance            ']
# 5       ['Action, Adventure, Sci-Fi            ']
# 6        ['Biography, Comedy, Drama            ']
# 7        ['Comedy, Fantasy, Romance            ']
# 8          ['Drama, Horror, Mystery            ']
# 9    ['Animation, Action, Adventure            ']
# 10                         ['Comedy            ']
# 11      ['Action, Adventure, Sci-Fi            ']
# 12      ['Biography, Drama, Western            ']
# 13   ['Animation, Adventure, Comedy            ']
# 14                       ['Thriller            ']
# 15            ['Drama, Romance, War            ']
# 16      ['Horror, Mystery, Thriller            ']
# 17       ['Drama, History, Thriller            ']
# 18     ['Adventure, Family, Fantasy            ']
# 19                         ['Comedy            ']
# 20      ['Action, Adventure, Comedy            ']
# 21      ['Horror, Mystery, Thriller            ']
# 22      ['Biography, Drama, History            ']
# 23     ['Action, Adventure, Fantasy            ']
# 24       ['Comedy, Fantasy, Romance            ']
# 25   ['Animation, Adventure, Comedy            ']
# 26      ['Horror, Mystery, Thriller            ']
# 27      ['Action, Adventure, Sci-Fi            ']
# 28   ['Animation, Adventure, Comedy            ']
# 29                ['Comedy, Romance            ']
# ..                                            ...
# 73      ['Animation, Comedy, Family            ']
# 74                          ['Drama            ']
# 75     ['Adventure, Family, Fantasy            ']
# 76             ['Comedy, Drama, War            ']
# 77                   ['Drama, Sport            ']
# 78      ['Action, Adventure, Sci-Fi            ']
# 79                   ['Crime, Drama            ']
# 80                         ['Horror            ']
# 81       ['Action, Biography, Drama            ']
# 82      ['Action, Adventure, Comedy            ']
# 83                          ['Drama            ']
# 84                ['Comedy, Romance            ']
# 85   ['Animation, Adventure, Comedy            ']
# 86               ['Biography, Drama            ']
# 87         ['Action, Drama, Mystery            ']
# 88          ['Crime, Drama, Mystery            ']
# 89                          ['Drama            ']
# 90      ['Action, Adventure, Comedy            ']
# 91      ['Horror, Mystery, Thriller            ']
# 92     ['Action, Adventure, Fantasy            ']
# 93       ['Animation, Comedy, Drama            ']
# 94   ['Animation, Action, Adventure            ']
# 95                 ['Action, Comedy            ']
# 96                 ['Drama, Romance            ']
# 97                     ['Drama, War            ']
# 98                  ['Drama, Sci-Fi            ']
# 99                        ['Romance            ']
# 100                ['Drama, Fantasy            ']
# 101       ['Action, Fantasy, Horror            ']
# 102                        ['Horror            ']
#
#                                                name
# 0                                             Glass
# 1                         The Kid Who Would Be King
# 2                                         Miss Bala
# 3                 The Lego Movie 2: The Second Part
# 4                                     What Men Want
# 5                               Alita: Battle Angel
# 6                           Fighting with My Family
# 7                                 Isn't It Romantic
# 8                                Happy Death Day 2U
# 9        How to Train Your Dragon: The Hidden World
# 10                           A Madea Family Funeral
# 11                                   Captain Marvel
# 12                                          The Kid
# 13                                      Wonder Park
# 14                          The Hummingbird Project
# 15                                    The Aftermath
# 16                                               Us
# 17                                     Hotel Mumbai
# 18                                            Dumbo
# 19                                    The Beach Bum
# 20                                          Shazam!
# 21                                     Pet Sematary
# 22                              The Best of Enemies
# 23                                          Hellboy
# 24                                           Little
# 25                                     Missing Link
# 26                          The Curse of La Llorona
# 27                                Avengers: Endgame
# 28                                        UglyDolls
# 29                                        Long Shot
# ..                                              ...
# 73                                The Addams Family
# 74                                    The Goldfinch
# 75                     Maleficent: Mistress of Evil
# 76                                      Jojo Rabbit
# 77                                         Torrance
# 78                            Terminator: Dark Fate
# 79                              Motherless Brooklyn
# 80                                     Doctor Sleep
# 81                                   Ford v Ferrari
# 82                                 Charlie's Angels
# 83                                    The Good Liar
# 84                                   Last Christmas
# 85                                        Frozen II
# 86              A Beautiful Day in the Neighborhood
# 87                               The Rhythm Section
# 88                                       Knives Out
# 89                                     Queen & Slim
# 90   Untitled Jumanji: Welcome to the Jungle Sequel
# 91                                  Black Christmas
# 92                 Star Wars: The Rise of Skywalker
# 93                                             Cats
# 94                                Spies in Disguise
# 95                                Superintelligence
# 96                                     Little Women
# 97                                             1917
# 98                                  Lucy in the Sky
# 99                                The Rosie Project
# 100                                           Wendy
# 101                                           Spawn
# 102                                             Eli
#
# [103 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(df['genre'])
tfidf_matrix.shape
# Out:
# (103, 70)

# %%
from sklearn.metrics.pairwise import linear_kernel
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
cosine_sim[:4, :4]
# Out:
# array([[1.        , 0.        , 0.0607877 , 0.        ],
#        [0.        , 1.        , 0.09284477, 0.35346896],
#        [0.0607877 , 0.09284477, 1.        , 0.09674378],
#        [0.        , 0.35346896, 0.09674378, 1.        ]])

# %%
# Build a 1-dimensional array with movie titles
titles = df['name']
indices = pd.Series(df.index, index=df['name'])

# Function that get movie recommendations based on the cosine similarity score of movie genres
def genre_recommendations(title):
#     newtitle = title + '\xa0'
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:21]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]

# %%
genre_recommendations('Captain Marvel').head(20)
# Out:
# 11                                    Captain Marvel
# 27                                 Avengers: Endgame
# 40                                      Dark Phoenix
# 48                         Spider-Man: Far from Home
# 78                             Terminator: Dark Fate
# 98                                   Lucy in the Sky
# 36                                        Brightburn
# 70                                        Gemini Man
# 68                                Doom: Annihilation
# 0                                              Glass
# 20                                           Shazam!
# 30                         Pokémon Detective Pikachu
# 42                       Men in Black: International
# 52             Fast & Furious Presents: Hobbs & Shaw
# 82                                  Charlie's Angels
# 90    Untitled Jumanji: Welcome to the Jungle Sequel
# 3                  The Lego Movie 2: The Second Part
# 9         How to Train Your Dragon: The Hidden World
# 94                                 Spies in Disguise
# 23                                           Hellboy
# Name: name, dtype: object
